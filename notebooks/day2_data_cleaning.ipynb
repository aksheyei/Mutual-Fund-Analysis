# %% [markdown]
# #### IMPORTING LIBRARIES

# %%
import pandas as pd;

# %% [markdown]
# ##### IMPORTING DATA

# %%
nav_history=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\BLUE STOCK INTERNSHIP\Mutual-Fund-Analysis\data\raw\02_nav_history.csv")
investor_transactions=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\BLUE STOCK INTERNSHIP\Mutual-Fund-Analysis\data\raw\08_investor_transactions.csv")
scheme_performance=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\BLUE STOCK INTERNSHIP\Mutual-Fund-Analysis\data\raw\07_scheme_performance.csv")
fund_master=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\BLUE STOCK INTERNSHIP\Mutual-Fund-Analysis\data\raw\01_fund_master.csv")

# %% [markdown]
# ###### NAV_HISTORY

# %%
nav_history.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
# Checking data types
nav_history.dtypes
# Out:
# amfi_code      int64
# date             str
# nav          float64
# dtype: object

# %%
# Checking for duplicates
nav_history.duplicated().sum()
# Out:
# np.int64(0)

# %%
# checking missing values
nav_history.isnull().sum()
# Out:
# amfi_code    0
# date         0
# nav          0
# dtype: int64

# %%
# validating nav > 0
nav_history[nav_history['nav']<=0]
# Out:
# Empty DataFrame
# Columns: [amfi_code, date, nav]
# Index: []

# %%
# changing the STR data type of date into DATE data type
nav_history['date']=pd.to_datetime(
    nav_history['date'])

# %%
# Arranging the data in amfi_code and date order
nav_history=nav_history.sort_values(by=['amfi_code','date'],ascending=True)
nav_history
# Out:
#        amfi_code       date       nav
# 5750      100016 2022-01-03  520.4608
# 5751      100016 2022-01-04  515.0971
# 5752      100016 2022-01-05  521.7239
# 5753      100016 2022-01-06  515.7880
# 5754      100016 2022-01-07  515.1639
# ...          ...        ...       ...
# 45995     149324 2026-05-25  292.4810
# 45996     149324 2026-05-26  291.2707
# 45997     149324 2026-05-27  288.8007
# 45998     149324 2026-05-28  280.6873
# 45999     149324 2026-05-29  279.7511
#
# [46000 rows x 3 columns]

# %% [markdown]
# ##### INVESTOR_TRANSACTIONS

# %%
investor_transactions.dtypes
# Out:
# investor_id               str
# transaction_date          str
# amfi_code               int64
# transaction_type          str
# amount_inr              int64
# state                     str
# city                      str
# city_tier                 str
# age_group                 str
# gender                    str
# annual_income_lakh    float64
# payment_mode              str
# kyc_status                str
# dtype: object

# %%
investor_transactions.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
# correcting the transaction date column into DATE data type
investor_transactions['transaction_date']=pd.to_datetime(
    investor_transactions['transaction_date'])

# %%
# checking any amounts less than zero exists
investor_transactions[investor_transactions['amount_inr']<=0]
# Out:
# Empty DataFrame
# Columns: [investor_id, transaction_date, amfi_code, transaction_type, amount_inr, state, city, city_tier, age_group, gender, annual_income_lakh, payment_mode, kyc_status]
# Index: []

# %%
# checking values in kyc status
investor_transactions['kyc_status'].unique()
# Out:
# <StringArray>
# ['Verified', 'Pending']
# Length: 2, dtype: str

# %% [markdown]
# ##### SCHEME PERFORMANCE

# %%
scheme_performance.dtypes
# Out:
# amfi_code               int64
# scheme_name               str
# fund_house                str
# category                  str
# plan                      str
# return_1yr_pct        float64
# return_3yr_pct        float64
# return_5yr_pct        float64
# benchmark_3yr_pct     float64
# alpha                 float64
# beta                  float64
# sharpe_ratio          float64
# sortino_ratio         float64
# std_dev_ann_pct       float64
# max_drawdown_pct      float64
# aum_crore               int64
# expense_ratio_pct     float64
# morningstar_rating      int64
# risk_grade                str
# dtype: object

# %%
scheme_performance.head()
# Out:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# ...

# %%
# validating expense ratio pct
scheme_performance[scheme_performance['expense_ratio_pct']<=0.1]
# Out:
# Empty DataFrame
# Columns: [amfi_code, scheme_name, fund_house, category, plan, return_1yr_pct, return_3yr_pct, return_5yr_pct, benchmark_3yr_pct, alpha, beta, sharpe_ratio, sortino_ratio, std_dev_ann_pct, max_drawdown_pct, aum_crore, expense_ratio_pct, morningstar_rating, risk_grade]
# Index: []

# %%
investor_transactions["transaction_type"] = investor_transactions["transaction_type"].replace("Sip", "SIP")
investor_transactions["transaction_type"].unique()
# Out:
# <StringArray>
# ['SIP', 'Redemption', 'Lumpsum']
# Length: 3, dtype: str

# %%
fund_master.dtypes
# Out:
# amfi_code               int64
# fund_house                str
# scheme_name               str
# category                  str
# sub_category              str
# plan                      str
# launch_date               str
# benchmark                 str
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager              str
# risk_category             str
# sebi_category_code        str
# dtype: object

# %%
fund_master['launch_date']=pd.to_datetime(fund_master['launch_date'])

# %%
fund_master.columns
# Out:
# Index(['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category',
#        'plan', 'launch_date', 'benchmark', 'expense_ratio_pct',
#        'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager',
#        'risk_category', 'sebi_category_code'],
#       dtype='str')

# %%
nav_history.columns
# Out:
# Index(['amfi_code', 'date', 'nav'], dtype='str')

# %%
investor_transactions.columns
# Out:
# Index(['investor_id', 'transaction_date', 'amfi_code', 'transaction_type',
#        'amount_inr', 'state', 'city', 'city_tier', 'age_group', 'gender',
#        'annual_income_lakh', 'payment_mode', 'kyc_status'],
#       dtype='str')

# %%
scheme_performance.columns
# Out:
# Index(['amfi_code', 'scheme_name', 'fund_house', 'category', 'plan',
#        'return_1yr_pct', 'return_3yr_pct', 'return_5yr_pct',
#        'benchmark_3yr_pct', 'alpha', 'beta', 'sharpe_ratio', 'sortino_ratio',
#        'std_dev_ann_pct', 'max_drawdown_pct', 'aum_crore', 'expense_ratio_pct',
#        'morningstar_rating', 'risk_grade'],
#       dtype='str')

# %%
aum_by_fund_house = pd.read_csv("../data/raw/03_aum_by_fund_house.csv")

# %%
aum_by_fund_house['date']=pd.to_datetime(aum_by_fund_house['date'])
aum_by_fund_house.dtypes
# Out:
# date              datetime64[us]
# fund_house                   str
# aum_lakh_crore           float64
# aum_crore                  int64
# num_schemes                int64
# dtype: object

# %%
aum_by_fund_house.columns
# Out:
# Index(['date', 'fund_house', 'aum_lakh_crore', 'aum_crore', 'num_schemes'], dtype='str')

# %% [markdown]
# ##### IMPORTING NEW LIBRARY

# %%
from sqlalchemy import create_engine

# %%
# creating engine
engine = create_engine("sqlite:///../bluestock_mf.db")

# %%
# CREATING dim_fund table
with engine.connect() as conn:
    conn.exec_driver_sql("""
    CREATE TABLE dim_fund(
    amfi_code INTEGER PRIMARY KEY,
    fund_house TEXT,
    scheme_name TEXT,
    category TEXT,
    sub_category TEXT,
    plan TEXT,
    launch_date TEXT,
    benchmark TEXT,
    expense_ratio_pct REAL,
    exit_load_pct REAL,
    min_sip_amount INTEGER,
    min_lumpsum_amount INTEGER,
    fund_manager TEXT,
    risk_category TEXT,
    sebi_category_code TEXT
    )""")
    conn.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\OneDrive\Desktop\BLUE STOCK INTERNSHIP\Mutual-Fund-Analysis\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~\OneDrive\Desktop\BLUE STOCK INTERNSHIP\Mutual-Fund-Analysis\.venv\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: table dim_fund already exists
#
# ...

# %%
# creating dim_table
with engine.connect() as conn:
    conn.exec_driver_sql("""
    CREATE TABLE dim_date(
     date_id INTEGER PRIMARY KEY,
    full_date TEXT,
    year INTEGER,
    month INTEGER,
    month_name TEXT,
    quarter INTEGER,
    day_of_week TEXT,
    is_weekend INTEGER
    )""")
    conn.commit()

# %%
# creating fact_nav
with engine.connect() as conn:
    conn.exec_driver_sql("""
    CREATE TABLE fact_nav(
    nav_id INTEGER PRIMARY KEY,
    amfi_code INTEGER,
    date_id INTEGER,
    nav REAL,
    FOREIGN KEY (amfi_code) REFERENCES dim_fund(amfi_code),
    FOREIGN KEY (date_id) REFERENCES dim_date(date_id)
    )""")
    conn.commit()

# %%
# creating fact_transactions
with engine.connect() as conn:
    conn.exec_driver_sql("""
    CREATE TABLE fact_transactions (
    transaction_id INTEGER PRIMARY KEY,
    investor_id TEXT,
    amfi_code INTEGER,
    date_id INTEGER,
    transaction_type TEXT,
    amount_inr INTEGER,
    state TEXT,
    city TEXT,
    city_tier TEXT,
    age_group TEXT,
    gender TEXT,
    annual_income_lakh REAL,
    payment_mode TEXT,
    kyc_status TEXT,
    FOREIGN KEY (amfi_code) REFERENCES dim_fund(amfi_code),
    FOREIGN KEY (date_id) REFERENCES dim_date(date_id)
    )""")
    conn.commit()

# %%
# creating fact_performance table
with engine.connect() as conn:
    conn.exec_driver_sql("""
    CREATE TABLE fact_performance (
    performance_id INTEGER PRIMARY KEY,
    amfi_code INTEGER,
    return_1yr_pct REAL,
    return_3yr_pct REAL,
    return_5yr_pct REAL,
    benchmark_3yr_pct REAL,
    alpha REAL,
    beta REAL,
    sharpe_ratio REAL,
    sortino_ratio REAL,
    std_dev_ann_pct REAL,
    max_drawdown_pct REAL,
    aum_crore INTEGER,
    expense_ratio_pct REAL,
    morningstar_rating INTEGER,
    risk_grade TEXT,
    FOREIGN KEY (amfi_code) REFERENCES dim_fund(amfi_code)
    )""")
    conn.commit()

# %%
# creating fact_aum table
with engine.connect() as conn:
    conn.exec_driver_sql("""
    CREATE TABLE fact_aum (
    aum_id INTEGER PRIMARY KEY,
    date_id INTEGER,
    fund_house TEXT,
    aum_lakh_crore REAL,
    aum_crore INTEGER,
    num_schemes INTEGER,
    FOREIGN KEY (date_id) REFERENCES dim_date(date_id)
    )""")
    conn.commit()

# %%
pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", engine)
# Out:
#                 name
# 0           dim_fund
# 1           dim_date
# 2           fact_nav
# 3  fact_transactions
# 4   fact_performance
# 5           fact_aum

# %%
# inserting table data into sql database
fund_master.to_sql("dim_fund", engine, if_exists="append", index=False)

# %%
nav_history["date"].min(), nav_history["date"].max()
# Out:
# (Timestamp('2022-01-03 00:00:00'), Timestamp('2026-05-29 00:00:00'))

# %%
#creating a date range
date_range = pd.date_range(start="2022-01-01", end="2026-12-31", freq="D")
date_range
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2026-12-22', '2026-12-23', '2026-12-24', '2026-12-25',
#                '2026-12-26', '2026-12-27', '2026-12-28', '2026-12-29',
#                '2026-12-30', '2026-12-31'],
#               dtype='datetime64[us]', length=1826, freq='D')

# %%
dim_date = pd.DataFrame({
    "full_date": date_range.strftime("%Y-%m-%d"),
    "year": date_range.year,
    "month": date_range.month,
    "month_name": date_range.strftime("%B"),
    "quarter": date_range.quarter,
    "day_of_week": date_range.strftime("%A"),
    "is_weekend": date_range.dayofweek.isin([5, 6]).astype(int)
})

dim_date.head()
# Out:
#     full_date  year  month month_name  quarter day_of_week  is_weekend
# 0  2022-01-01  2022      1    January        1    Saturday           1
# 1  2022-01-02  2022      1    January        1      Sunday           1
# 2  2022-01-03  2022      1    January        1      Monday           0
# 3  2022-01-04  2022      1    January        1     Tuesday           0
# 4  2022-01-05  2022      1    January        1   Wednesday           0

# %%
dim_date.insert(0, "date_id", range(1, len(dim_date) + 1))
dim_date.head()
# Out:
#    date_id   full_date  year  month month_name  quarter day_of_week  \
# 0        1  2022-01-01  2022      1    January        1    Saturday
# 1        2  2022-01-02  2022      1    January        1      Sunday
# 2        3  2022-01-03  2022      1    January        1      Monday
# 3        4  2022-01-04  2022      1    January        1     Tuesday
# 4        5  2022-01-05  2022      1    January        1   Wednesday
#
#    is_weekend
# 0           1
# 1           1
# 2           0
# 3           0
# 4           0

# %%
# inseting data into dim_date 
dim_date.to_sql("dim_date", engine, if_exists="append", index=False)
# Out:
# 1826

# %%
pd.read_sql("SELECT * FROM dim_date LIMIT 5;", engine)
# Out:
#    date_id   full_date  year  month month_name  quarter day_of_week  \
# 0        1  2022-01-01  2022      1    January        1    Saturday
# 1        2  2022-01-02  2022      1    January        1      Sunday
# 2        3  2022-01-03  2022      1    January        1      Monday
# 3        4  2022-01-04  2022      1    January        1     Tuesday
# 4        5  2022-01-05  2022      1    January        1   Wednesday
#
#    is_weekend
# 0           1
# 1           1
# 2           0
# 3           0
# 4           0

# %%
dim_date_lookup = pd.read_sql("SELECT date_id, full_date FROM dim_date;", engine)
dim_date_lookup["full_date"] = pd.to_datetime(dim_date_lookup["full_date"])
dim_date_lookup.head()
# Out:
#    date_id  full_date
# 0        1 2022-01-01
# 1        2 2022-01-02
# 2        3 2022-01-03
# 3        4 2022-01-04
# 4        5 2022-01-05

# %%
# inserting data inside fact_nav
fact_nav = nav_history.merge(dim_date_lookup, left_on="date", right_on="full_date", how="left")
fact_nav.head()
# Out:
#    amfi_code       date       nav  date_id  full_date
# 0     100016 2022-01-03  520.4608        3 2022-01-03
# 1     100016 2022-01-04  515.0971        4 2022-01-04
# 2     100016 2022-01-05  521.7239        5 2022-01-05
# 3     100016 2022-01-06  515.7880        6 2022-01-06
# 4     100016 2022-01-07  515.1639        7 2022-01-07

# %%
fact_nav = fact_nav[["amfi_code", "date_id", "nav"]]
fact_nav.head()
# Out:
#    amfi_code  date_id       nav
# 0     100016        3  520.4608
# 1     100016        4  515.0971
# 2     100016        5  521.7239
# 3     100016        6  515.7880
# 4     100016        7  515.1639

# %%
fact_nav.to_sql("fact_nav",engine, if_exists='append',index=False)
pd.read_sql("SELECT * FROM fact_nav LIMIT 5;", engine)
# Out:
#    nav_id  amfi_code  date_id       nav
# 0       1     100016        3  520.4608
# 1       2     100016        4  515.0971
# 2       3     100016        5  521.7239
# 3       4     100016        6  515.7880
# 4       5     100016        7  515.1639

# %%
investor_transactions.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
dim_date_lookup.head()
# Out:
#    date_id  full_date
# 0        1 2022-01-01
# 1        2 2022-01-02
# 2        3 2022-01-03
# 3        4 2022-01-04
# 4        5 2022-01-05

# %%
# merging the tables
fact_transactions=investor_transactions.merge(dim_date_lookup,left_on ='transaction_date',right_on='full_date',how='left')
fact_transactions.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status  date_id  full_date
# 0          UPI   Verified      731 2024-01-01
# ...

# %%
# removing unwanted columns (transaction_date,full_dates)
fact_transactions=fact_transactions[['investor_id','amfi_code','date_id','transaction_type','amount_inr','state','city','city_tier',
                                     'age_group','gender','annual_income_lakh','payment_mode','kyc_status']]
fact_transactions.head()
# Out:
#   investor_id  amfi_code  date_id transaction_type  amount_inr        state  \
# 0   INV003054     119092      731              SIP        1834    Telangana
# 1   INV002952     148567      731       Redemption      392882       Punjab
# 2   INV003420     118636      731              SIP         912      Haryana
# 3   INV003436     118634      731              SIP        1102  Maharashtra
# 4   INV004691     119094      731          Lumpsum        8682        Delhi
#
#         city city_tier age_group  gender  annual_income_lakh payment_mode  \
# 0  Hyderabad       T30       56+  Female                77.1          UPI
# 1   Amritsar       B30     18-25    Male                 7.1       Cheque
# 2  Faridabad       B30     36-45    Male                47.2      Mandate
# 3     Mumbai       T30     36-45  Female                54.4       Cheque
# 4      Noida       T30     26-35    Male                14.5  Net Banking
#
#   kyc_status
# 0   Verified
# 1   Verified
# 2   Verified
# ...

# %%
# loading data into sql fact_transaction
fact_transactions.to_sql("fact_transactions", engine, if_exists="append", index=False)
pd.read_sql("SELECT * FROM fact_transactions LIMIT 5;", engine)
# Out:
#    transaction_id investor_id  amfi_code  date_id transaction_type  \
# 0               1   INV003054     119092      731              SIP
# 1               2   INV002952     148567      731       Redemption
# 2               3   INV003420     118636      731              SIP
# 3               4   INV003436     118634      731              SIP
# 4               5   INV004691     119094      731          Lumpsum
#
#    amount_inr        state       city city_tier age_group  gender  \
# 0        1834    Telangana  Hyderabad       T30       56+  Female
# 1      392882       Punjab   Amritsar       B30     18-25    Male
# 2         912      Haryana  Faridabad       B30     36-45    Male
# 3        1102  Maharashtra     Mumbai       T30     36-45  Female
# 4        8682        Delhi      Noida       T30     26-35    Male
#
#    annual_income_lakh payment_mode kyc_status
# 0                77.1          UPI   Verified
# 1                 7.1       Cheque   Verified
# ...

# %%
scheme_performance.columns
# Out:
# Index(['amfi_code', 'scheme_name', 'fund_house', 'category', 'plan',
#        'return_1yr_pct', 'return_3yr_pct', 'return_5yr_pct',
#        'benchmark_3yr_pct', 'alpha', 'beta', 'sharpe_ratio', 'sortino_ratio',
#        'std_dev_ann_pct', 'max_drawdown_pct', 'aum_crore', 'expense_ratio_pct',
#        'morningstar_rating', 'risk_grade'],
#       dtype='str')

# %%
# Drop duplicate columns (columns already in dim_fund)
fact_performance = scheme_performance.drop(columns=["scheme_name", "fund_house", "category", "plan"])
fact_performance.head()
# Out:
#    amfi_code  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0     119551           12.42           12.36           14.45
# 1     119552           15.25           11.30           14.23
# 2     119598           24.56           23.39           20.67
# 3     119599           20.59           23.14           21.82
# 4     119120            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# 0              11.49   0.87  0.89          0.88           1.29
# 1               9.52   1.78  0.87          0.81           1.29
# 2              22.16   1.23  0.89          0.94           1.35
# 3              22.01   1.13  1.04          0.93           1.67
# 4               4.47   1.60  0.22          1.52           2.11
#
#    std_dev_ann_pct  max_drawdown_pct  aum_crore  expense_ratio_pct  \
# 0             14.0            -21.70      14288               1.54
# 1             14.0            -24.43       1231               0.66
# ...

# %%
# loading data 
fact_performance.to_sql("fact_performance", engine, if_exists="append", index=False)
pd.read_sql("SELECT * FROM fact_performance LIMIT 5;",engine)
# Out:
#    performance_id  amfi_code  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0               1     119551           12.42           12.36           14.45
# 1               2     119552           15.25           11.30           14.23
# 2               3     119598           24.56           23.39           20.67
# 3               4     119599           20.59           23.14           21.82
# 4               5     119120            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# 0              11.49   0.87  0.89          0.88           1.29
# 1               9.52   1.78  0.87          0.81           1.29
# 2              22.16   1.23  0.89          0.94           1.35
# 3              22.01   1.13  1.04          0.93           1.67
# 4               4.47   1.60  0.22          1.52           2.11
#
#    std_dev_ann_pct  max_drawdown_pct  aum_crore  expense_ratio_pct  \
# ...

# %%
# importing aum_by_fund_house data
aum_by_fund_house=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\BLUE STOCK INTERNSHIP\Mutual-Fund-Analysis\data\raw\03_aum_by_fund_house.csv")
aum_by_fund_house.head()
# Out:
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168

# %%
aum_by_fund_house.dtypes
# Out:
# date                  str
# fund_house            str
# aum_lakh_crore    float64
# aum_crore           int64
# num_schemes         int64
# dtype: object

# %%
# changing date into Date data ype
aum_by_fund_house['date']=pd.to_datetime(aum_by_fund_house['date'])

# %%
dim_date_lookup.head()
# Out:
#    date_id  full_date
# 0        1 2022-01-01
# 1        2 2022-01-02
# 2        3 2022-01-03
# 3        4 2022-01-04
# 4        5 2022-01-05

# %%
# merging for including date_id column in aum
fact_aum=aum_by_fund_house.merge(dim_date_lookup,left_on='date',right_on='full_date',how='left')
fact_aum.head()
# Out:
#         date           fund_house  aum_lakh_crore  aum_crore  num_schemes  \
# 0 2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1 2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2 2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3 2022-03-31      Nippon India MF            2.70     270000          177
# 4 2022-03-31    Kotak Mahindra MF            2.70     270000          168
#
#    date_id  full_date
# 0       90 2022-03-31
# 1       90 2022-03-31
# 2       90 2022-03-31
# 3       90 2022-03-31
# 4       90 2022-03-31

# %%
fact_aum = fact_aum[["date_id", "fund_house", "aum_lakh_crore", "aum_crore", "num_schemes"]]
fact_aum.head()
# Out:
#    date_id           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0       90      SBI Mutual Fund            6.05     605000          186
# 1       90  ICICI Prudential MF            4.65     465000          216
# 2       90     HDFC Mutual Fund            4.35     435000          195
# 3       90      Nippon India MF            2.70     270000          177
# 4       90    Kotak Mahindra MF            2.70     270000          168

# %%
fact_aum.to_sql("fact_aum", engine, if_exists="append", index=False)
pd.read_sql('SELECT * FROM fact_aum LIMIT 5;',engine)
# Out:
#    aum_id  date_id           fund_house  aum_lakh_crore  aum_crore  \
# 0       1       90      SBI Mutual Fund            6.05     605000
# 1       2       90  ICICI Prudential MF            4.65     465000
# 2       3       90     HDFC Mutual Fund            4.35     435000
# 3       4       90      Nippon India MF            2.70     270000
# 4       5       90    Kotak Mahindra MF            2.70     270000
#
#    num_schemes
# 0          186
# 1          216
# 2          195
# 3          177
# 4          168

# %%
print("dim_fund:", pd.read_sql("SELECT COUNT(*) FROM dim_fund;", engine).iloc[0,0], "vs fund_master:", fund_master.shape[0])
print("fact_nav:", pd.read_sql("SELECT COUNT(*) FROM fact_nav;", engine).iloc[0,0], "vs nav_history:", nav_history.shape[0])
print("fact_transactions:", pd.read_sql("SELECT COUNT(*) FROM fact_transactions;", engine).iloc[0,0], "vs investor_transactions:", investor_transactions.shape[0])
print("fact_performance:", pd.read_sql("SELECT COUNT(*) FROM fact_performance;", engine).iloc[0,0], "vs scheme_performance:", scheme_performance.shape[0])
print("fact_aum:", pd.read_sql("SELECT COUNT(*) FROM fact_aum;", engine).iloc[0,0], "vs aum_by_fund_house:", aum_by_fund_house.shape[0])
# Out:
# dim_fund: 40 vs fund_master: 40
# fact_nav: 46000 vs nav_history: 46000
# fact_transactions: 32778 vs investor_transactions: 32778
# fact_performance: 40 vs scheme_performance: 40
# fact_aum: 90 vs aum_by_fund_house: 90

# %%
with engine.connect() as conn:
    conn.exec_driver_sql("DELETE FROM fact_performance;")
    conn.exec_driver_sql("DELETE FROM fact_aum;")
    conn.commit()

# %%
fact_performance.to_sql("fact_performance", engine, if_exists="append", index=False)
fact_aum.to_sql("fact_aum", engine, if_exists="append", index=False)
# Out:
# 90

# %%
print("fact_performance:", pd.read_sql("SELECT COUNT(*) FROM fact_performance;", engine).iloc[0,0], "vs scheme_performance:", scheme_performance.shape[0])
print("fact_aum:", pd.read_sql("SELECT COUNT(*) FROM fact_aum;", engine).iloc[0,0], "vs aum_by_fund_house:", aum_by_fund_house.shape[0])
# Out:
# fact_performance: 40 vs scheme_performance: 40
# fact_aum: 90 vs aum_by_fund_house: 90
